# %% [markdown]
# Primera instruccion para abrir una archivo

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import os
directorio_actual = os.getcwd()
print(f"El directorio de trabajo actual es: {directorio_actual}")
img = imageio.imread('image2.png')
im = np.clip(img/255.,0,1)
print(im.shape,im.dtype)
plt.imshow(im)
plt.show()
im2 = im[:,:,[0,0,1]]
plt.imshow(im2)
plt.show()

imageio.imwrite('myImage.png',np.clip(im2*255,0,255).astype(np.uint8))
# Out:
# El directorio de trabajo actual es: /content
# (500, 1000, 3) float64
# /tmp/ipython-input-1084464285.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('image2.png')
