# %% [markdown]
# Primera instruccion para abrir una archivo

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import os
directorio_actual = os.getcwd()
print(f"El directorio de trabajo actual es: {directorio_actual}")
img = imageio.imread('image2.png')
im = np.clip(img/255.,0,1)
plt.imshow(im)
plt.show()
# Out:
# El directorio de trabajo actual es: /content
# /tmp/ipython-input-114754148.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('image2.png')
